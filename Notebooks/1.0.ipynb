# %%
# %pip install -U langchain
# Requires Python 3.10+
# Out:
# ...
#   Using cached langchain-1.1.0-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached langchain_core-1.1.0-py3-none-any.whl.metadata (3.6 kB)
# ...
# Using cached langchain-1.1.0-py3-none-any.whl (101 kB)
# Using cached langchain_core-1.1.0-py3-none-any.whl (473 kB)
# ...
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/home/pranavtyagi/miniforge3/envs/langchain/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 438, in _error_catcher
#     yield
#   File "/home/pranavtyagi/miniforge3/envs/langchain/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 561, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "/home/pranavtyagi/miniforge3/envs/langchain/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 527, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
# ...

# %%
from langchain.agents import create_openai_tools_agent
